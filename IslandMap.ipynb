# %%
#!/usr/bin/python3
__author__ = '@Tssp'

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pyMap import *
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13
plt.rcParams['axes.labelsize']=16
plt.rcParams['axes.titlesize']=16

# %%
lon = [-22-51/60, -21.9] 
lat = [63+41/60, 64+13/60]
Map_obj = Map(lon, lat, EPSG=3832)
# Out:
# Longitudes: [-22.85, -21.9]
# Latitudes: [63.68333333333333, 64.21666666666667]
# EPSG: 3832
# Service: ESRI_Imagery_World_2D
#
# Obtain your epsg code from this web:
# https://epsg.io/3832

# %%
m = Map_obj.createMap(figsize=(10, 10))
Map_obj.plotMap(m)
# Out:
# /Users/tssp/Library/Python/3.7/lib/python/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_Imagery_World_2D/MapServer/export?bbox=-19241573.98361734,9231460.766573226,-19135820.467363726,9366482.098042393&bboxSR=3832&imageSR=3832&size=1000,1276&dpi=96&format=png32&transparent=true&f=image
